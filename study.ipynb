# %%
# 1,2,3,4,5

def add(a,b):
    print(a+b)

add(1,2)

for i in range(1,17+1):
    print(i)

# %%
import requests
import json
from datetime import datetime, timedelta

def main_request(page): #lấy dữ liệu từng page trả về file json
    current_time = datetime.now()
    before_70_minutes = current_time - timedelta(minutes=70)
    to_time = before_70_minutes.strftime("%Y-%m-%d %H:%M:%S")

    url = "https://open.nhanh.vn/api/order/index"

    payload = {'version': '2.0',
    'appId': '73670',
    'businessId': '41931',
    'accessToken': 'TgtXPMjeE6BtzFwgEMFJmGFRvwTDHQVgUnRIy4UvbX4YJME8QLh4LA5gz6uiS9eTtqYmQR0JHVsJDeclAffAR21ieqru6jFU9lG4BMTbtL5rlTw2rIVZHFm4aCaQdPpkIcTIce1ucMR90myfCb5NYJZmIvVP8vgwIbDspERlg1o2v6Jne04FCD6BTt5QWu6g5tdL',
    'data': '{"updatedFromDateTime":' + '"' + to_time + '"' + ',"page":' + str(page) + '}'
    }
    files=[

    ]
    headers = {}

    response = requests.request("POST", url, headers=headers, data=payload, files=files)

    return response.json()
    print(response.json())
# Out:
# {'code': 1,
#  'data': {'totalPages': 1,
#   'totalRecords': 34,
#   'page': 1,
#   'orders': {'328748517': {'id': 328748517,
#     'privateId': '2312255AC39SU6',
#     'shopOrderId': '2312255AC39SU6',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN03745934112C',
#     'depotId': 41944,
#     'handoverId': 1549716,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 0,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 22856,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'T******o',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '****** suối nghệ, huyện châu đức, tỉnh bà rịa vũng tàu, Xã Suối Nghệ, Huyện Châu Đức, Bà Rịa - Vũng Tàu',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2023-12-25 12:55:43',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Đã hoàn',
#     'statusCode': 'Returned',
#     'calcTotalMoney': 0,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105429',
#       'productName': 'Áo cách điệu cổ nơ lệch - Kem - S',
#       'productCode': 'AC341TN.LC1123-KE-S',
#       'productBarcode': '2000214266320',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231116_Wuy7pSvZJx.jpeg',
#       'price': '259000',
#       'quantity': '1',
#       'weight': None,
#       'discount': 0,
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '330283992': {'id': 330283992,
#     'privateId': '231229EXDKH90M',
#     'shopOrderId': '231229EXDKH90M',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN03563431198C',
#     'depotId': 41944,
#     'handoverId': 1549813,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 29880,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 47806,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'L******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ờng Hòa Minh, Quận Liên Chiểu, Đà Nẵng',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2023-12-29 08:48:25',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 529120,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105353',
#       'productName': 'Áo cadigan cổ tròn basic - Nâu - Free size',
#       'productCode': 'AL131LT.LP1023-NA-F',
#       'productBarcode': '2000214265569',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231109_1XC0tPw6oD.jpeg',
#       'price': '249000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '13310',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105649',
#       'productName': 'Tất ngắn cổ',
#       'productCode': 'QT200',
#       'productBarcode': '2000214268522',
#       'productImage': '',
#       'price': 0,
#       'quantity': '1',
#       'weight': None,
#       'discount': 0,
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39106042',
#       'productName': 'Áo cadigan cổ tròn basic - Nâu Vàng - Free size',
#       'productCode': 'AL131LT.LP1023-NV-F',
#       'productBarcode': '2000214272451',
#       'productImage': '',
#       'price': '310000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '16570',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '330914139': {'id': 330914139,
#     'privateId': '231231K3YD4A7D',
#     'shopOrderId': '231231K3YD4A7D',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN03079924988C',
#     'depotId': 41944,
#     'handoverId': 1549781,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 5000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 25034,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'L******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ng quận 9 TPHCM, Phường Long Trường, Thành Phố Thủ Đức, TP. Hồ Chí Minh',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2023-12-31 00:38:30',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': 260000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39103729',
#       'productName': 'váy dáng A can xòe tùng cổ bẻ - Hoa xanh - S',
#       'productCode': 'VA312RN.BC0523-HX-S',
#       'productBarcode': '2000214249323',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230526_6w3UVKsa1w.jpeg',
#       'price': '265000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '5000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '331149355': {'id': 331149355,
#     'privateId': '231231NAND1M2G',
#     'shopOrderId': '231231NAND1M2G',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN03882167422C',
#     'depotId': 41944,
#     'handoverId': 1549781,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 0,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 22677,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'N******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******hị Trấn Phước Bửu, Huyện Xuyên Mộc, Bà Rịa - Vũng Tàu',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2023-12-31 21:43:31',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': 209000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105127',
#       'productName': 'Áo dệt kim đáp vai tay ngắn - Nâu - L',
#       'productCode': 'AF127CT.LP1023-NA-L',
#       'productBarcode': '2000214263305',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230921_vwOrms2eQy.jpeg',
#       'price': '209000',
#       'quantity': '1',
#       'weight': None,
#       'discount': 0,
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '332051658': {'id': 332051658,
#     'privateId': '240102T8HA7FHB',
#     'shopOrderId': '240102T8HA7FHB',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN049314483621',
#     'depotId': 41944,
#     'handoverId': 1549798,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 19900,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 16439,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'M*****h',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******34 Ngô Tất Tố, Phường 22, Quận Bình Thạnh, TP. Hồ Chí Minh',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-02 20:48:45',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 179100,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105540',
#       'productName': 'Áo dệt kim đáp vai tay lửng. - Đen - L',
#       'productCode': 'AF127CT.LP1123-DE-L',
#       'productBarcode': '2000214267433',
#       'productImage': '',
#       'price': '199000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '19900',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '332528202': {'id': 332528202,
#     'privateId': '24010401ATM2GW',
#     'shopOrderId': '24010401ATM2GW',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN043000071651',
#     'depotId': 41944,
#     'handoverId': 1549813,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 20340,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 28819,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'H******n',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******, Phường Trung Tự, Quận Đống Đa, Hà Nội',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-04 00:17:17',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': 318660,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105402',
#       'productName': 'Cadigan phối viền - Tím than - Free size',
#       'productCode': 'AL134LT.LP1123-TT-F',
#       'productBarcode': '2000214266054',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231030_KuzEw4ME0j.jpeg',
#       'price': '339000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '20340',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '332657148': {'id': 332657148,
#     'privateId': '24010416TW6KSN',
#     'shopOrderId': '24010416TW6KSN',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN044834662821',
#     'depotId': 41944,
#     'handoverId': 1549813,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 30000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 91030,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'M******h',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '****** Phường 1, Thành Phố Tân An, Long An',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-04 11:28:26',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 1003000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39103951',
#       'productName': 'Váy dáng A chiết ly eo thắt đai sau - Xanh rêu - S',
#       'productCode': 'VA323KK.LC0723-XR-S',
#       'productBarcode': '2000214251548',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230616_yp66xT50YX.jpeg',
#       'price': '399500',
#       'quantity': '1',
#       'weight': None,
#       'discount': '11602',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39101432',
#       'productName': 'Váy midi cổ 2 ve đính cúc nẹp - Họa tiết - S',
#       'productCode': 'VM115TH.LC0523-HTT-S',
#       'productBarcode': '2000214248692',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230527_Sng9wUuTuX.jpeg',
#       'price': '319000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '9264',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39104141',
#       'productName': 'Áo croptop lượn gấu - Trắng - S',
#       'productCode': 'AC295TH.LP0723-TR-S',
#       'productBarcode': '2000214253443',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230927_ic1AGZeisP.jpeg',
#       'price': '314500',
#       'quantity': '1',
#       'weight': None,
#       'discount': '9134',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '332948653': {'id': 332948653,
#     'privateId': '2401042CFMHMH4',
#     'shopOrderId': '2401042CFMHMH4',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN040767504341',
#     'depotId': 41944,
#     'handoverId': 1549825,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 30000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 50085,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'T******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******2122, Phường Đông Hải, Thành Phố Thanh Hóa, Thanh Hóa',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-04 22:42:10',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 556500,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105603',
#       'productName': 'Áo khóac dạ cổ tròn phối tua rua - Đen - L',
#       'productCode': 'AK041DT.LP1223-DE-L',
#       'productBarcode': '2000214268065',
#       'productImage': '',
#       'price': '586500',
#       'quantity': '1',
#       'weight': None,
#       'discount': '30000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '332973026': {'id': 332973026,
#     'privateId': '2401052HJQ30YU',
#     'shopOrderId': '2401052HJQ30YU',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN046515354981',
#     'depotId': 41944,
#     'handoverId': 1549825,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 30000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 81720,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'Y****B',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ỵ, Hd Nội, Phường Ngọc Thụy, Quận Long Biên, Hà Nội',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-05 00:13:21',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 908000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105138',
#       'productName': 'Váy dáng xòe xoắn cổ dài tay - Đỏ - L',
#       'productCode': 'VX151TS.LP1023-DO-L',
#       'productBarcode': '2000214263411',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231019_iC0gzQGwx0.jpeg',
#       'price': '479000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '15320',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105003',
#       'productName': 'Váy dáng A phối tà lệch xếp ly chân - Đen - L',
#       'productCode': 'VA342XH.LP1023-DE-L',
#       'productBarcode': '2000214262063',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231031_ygprBUc1Fe.jpeg',
#       'price': '459000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '14680',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333015704': {'id': 333015704,
#     'privateId': '2401053C7JCP91',
#     'shopOrderId': '2401053C7JCP91',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'G898NBW4',
#     'depotId': 41944,
#     'handoverId': 1549830,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 20000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 5,
#     'carrierName': 'Giaohangnhanh',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': 'NVN333015704',
#     'shipFee': 0,
#     'codFee': 19730,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'C******n',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ờng Đê Hùng Vương), Xã Trung An, Thành Phố Mỹ Tho, Tiền Giang',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-05 08:10:19',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đang chuyển',
#     'statusCode': 'Shipping',
#     'calcTotalMoney': 209000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '38411454',
#       'productName': 'Set áo 2 dây + áo khoác nữ tính - xanh lá - Free size',
#       'productCode': 'Al115LT.LP0922-XL-F',
#       'productBarcode': '2000203902482',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20220917_ahzuDA2ELTFy6fSZDtfsTBwm.jpg',
#       'price': '229000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '20000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333437673': {'id': 333437673,
#     'privateId': '2401065UD7VP8N',
#     'shopOrderId': '2401065UD7VP8N',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN048152468601',
#     'depotId': 41944,
#     'handoverId': 1549840,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 110000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 99655,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'L******h',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ường Tân Dân, Thành Phố Việt Trì, Phú Thọ',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2024-01-06 07:47:14',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đã đóng gói',
#     'statusCode': 'Packed',
#     'calcTotalMoney': 990000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105659',
#       'productName': 'Áo dài dáng suông thêu hoa ngực - Kem - M',
#       'productCode': 'AD014TN.LT1223-KE-M',
#       'productBarcode': '2000214268621',
#       'productImage': '',
#       'price': '1100000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '110000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333485273': {'id': 333485273,
#     'privateId': '24010663VYHS2X',
#     'shopOrderId': '24010663VYHS2X',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN042222475351',
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 10000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 41622,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'T******Y',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******uối Ngô, Huyện Tân Châu, Tây Ninh',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2024-01-06 10:19:12',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đã xác nhận',
#     'statusCode': 'Confirmed',
#     'calcTotalMoney': 404000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105538',
#       'productName': 'Áo dệt kim đáp vai tay lửng. - Đen - S',
#       'productCode': 'AF127CT.LP1123-DE-S',
#       'productBarcode': '2000214267419',
#       'productImage': '',
#       'price': '219000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '5290',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39104290',
#       'productName': 'Quần baggy mí diễu ly - Be - S',
#       'productCode': 'QB027XH.LC0923-BE-S',
#       'productBarcode': '2000214254938',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230921_8jYh6PSTgx.jpeg',
#       'price': '195000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '4710',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333490951': {'id': 333490951,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 982000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 8,
#     'carrierName': 'Giao hàng tiết kiệm',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 26000,
#     'codFee': 0,
#     'customerShipFee': 30000,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': 125424285,
#     'customerName': 'Trương Quỳnh Nhi',
#     'customerEmail': None,
#     'customerMobile': '0909980787',
#     'customerAddress': '280A4 lương định của , an phú quận 2, sdt 0909980787',
#     'shipToCityLocationId': 255,
#     'shipToDistrictLocationId': '330',
#     'customerCityId': 255,
#     'customerCity': 'Hồ Chí Minh',
#     'customerDistrictId': 330,
#     'customerDistrict': 'Quận 2',
#     'shipToWardLocationId': 10390,
#     'customerWard': 'Phường An Phú',
#     'createdById': 3131729,
#     'createdByUserName': 'Trần Ánh Nhung',
#     'createdByName': 'Trần Ánh Nhung',
#     'saleId': 3131729,
#     'saleName': 'Trần Ánh Nhung',
#     'createdDateTime': '2024-01-06 10:33:45',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Đã xác nhận',
#     'statusCode': 'Confirmed',
#     'calcTotalMoney': 1328000,
#     'trafficSourceId': 761591,
#     'trafficSourceName': 'Promotion',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39104035',
#       'productName': 'Váy dáng bút chì cổ phối ren đính cúc trang trí - Be - S',
#       'productCode': 'VB011TS.LC0723-BE-S',
#       'productBarcode': '2000214252385',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231009_7tAx2E48Kz.jpeg',
#       'price': '540000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '270000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39003380',
#       'productName': 'Váy dáng A cổ vest vạt lệch đính cúc - Xanh - S',
#       'productCode': 'VA286TS.LC0423-XA-S',
#       'productBarcode': '2000208087894',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230609_qPpwzsbL4S.jpeg',
#       'price': '540000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '270000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '38895833',
#       'productName': 'Váy midi dáng bút chì cut out eo - Đen - S',
#       'productCode': 'VM082TS.LC0323-DE-S',
#       'productBarcode': '2000207246803',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230327_fpOQmLkr3L.jpeg',
#       'price': '410000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '205000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105029',
#       'productName': 'Áo blazer xẻ sau lệch - Be - S',
#       'productCode': 'AB066CH.LC1023-BE-S',
#       'productBarcode': '2000214262322',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231031_ehi92lUd90.jpeg',
#       'price': '790000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '237000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333493761': {'id': 333493761,
#     'privateId': '24010664NSWNN5',
#     'shopOrderId': '24010664NSWNN5',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 16000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 13100,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'M******h',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '****** chánh, Phường Trung Hòa, Quận Cầu Giấy, Hà Nội',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-06 10:33:05',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đã xác nhận',
#     'statusCode': 'Confirmed',
#     'calcTotalMoney': 144000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '38411377',
#       'productName': 'Áo 2 dây len tăm trẻ trung - Nâu - Free size',
#       'productCode': 'Al112LT.LP0922-NA-F',
#       'productBarcode': '2000203901805',
#       'productImage': '',
#       'price': '160000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '16000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333503754': {'id': 333503754,
#     'privateId': '240106661HWDQU',
#     'shopOrderId': '240106661HWDQU',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': 'SPXVN040183625371',
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 10000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 32380,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'T******h',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ng D3, Phường Phước Long B, Thành Phố Thủ Đức, TP. Hồ Chí Minh',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2024-01-06 10:57:33',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đã xác nhận',
#     'statusCode': 'Confirmed',
#     'calcTotalMoney': 319000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39104974',
#       'productName': 'Áo peplum cổ tròn - Xanh - S',
#       'productCode': 'PL036DT.LP1023-XA-S',
#       'productBarcode': '2000214261776',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230829_cXcv2wrZs2.jpeg',
#       'price': '329000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '10000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333506148': {'id': 333506148,
#     'privateId': '24010666DAMT33',
#     'shopOrderId': '24010666DAMT33',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 19900,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 16839,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'L******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ng, Thị Trấn Xuân Trường, Huyện Xuân Trường, Nam Định',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-06 11:04:08',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Mới',
#     'statusCode': 'New',
#     'calcTotalMoney': 179100,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105126',
#       'productName': 'Áo dệt kim đáp vai tay ngắn - Nâu - M',
#       'productCode': 'AF127CT.LP1023-NA-M',
#       'productBarcode': '2000214263299',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20230921_vwOrms2eQy.jpeg',
#       'price': '199000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '19900',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333508137': {'id': 333508137,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Khách trả lại hàng',
#     'typeId': 14,
#     'moneyDiscount': 412000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 0,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': 'fs+giảm 5%\nak064 xin kho tổng',
#     'customerId': 144911378,
#     'customerName': 'Loan Tran',
#     'customerEmail': None,
#     'customerMobile': '0911023242',
#     'customerAddress': '83/14 Lê Đại hành phường Nghĩa Lộ TP quảng Ngãi',
#     'shipToCityLocationId': 296,
#     'shipToDistrictLocationId': '746',
#     'customerCityId': 296,
#     'customerCity': 'Quảng Ngãi',
#     'customerDistrictId': 746,
#     'customerDistrict': 'Thành phố Quảng Ngãi',
#     'shipToWardLocationId': 8209,
#     'customerWard': 'Phường Nghĩa Lộ',
#     'createdById': 2994812,
#     'createdByUserName': 'Nguyễn Thị Bích',
#     'createdByName': 'Nguyễn Thị Bích',
#     'saleId': 3128527,
#     'saleName': 'Nguyễn Thị Hiền',
#     'createdDateTime': '2024-01-06 11:16:49',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': -2758000,
#     'trafficSourceId': 753531,
#     'trafficSourceName': 'Page',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105767',
#       'productName': 'Áo khoác dạ tweed phối tay - Nâu - M',
#       'productCode': 'AK061DT.LC1223-NA-M',
#       'productBarcode': '2000214269703',
#       'productImage': '',
#       'price': '870000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '44000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105858',
#       'productName': 'Áo khoác dạ tweed phối viền túi ngực - Đỏ - M',
#       'productCode': 'AK064DT.LP1223-DO-M',
#       'productBarcode': '2000214270617',
#       'productImage': '',
#       'price': '870000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '44000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105860',
#       'productName': 'Áo khoác dạ tweed phối viền túi ngực - Đen - M',
#       'productCode': 'AK064DT.LP1223-DE-M',
#       'productBarcode': '2000214270631',
#       'productImage': '',
#       'price': '870000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '44000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '38602224',
#       'productName': 'Váy dáng xòe cổ cách điệu sang chảnh - Đỏ - S',
#       'productCode': 'VX084TT.LT1222-DO-S',
#       'productBarcode': '2000205092730',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20221104_mgzR0XtiVgf4iOdK3v9VbAGA.jpg',
#       'price': '560000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '280000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '328864339',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333508676': {'id': 333508676,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Khách trả lại hàng',
#     'typeId': 14,
#     'moneyDiscount': 0,
#     'moneyDeposit': 1030000,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 0,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': 'Ship mang về sản phẩm nguyên tem mác',
#     'privateDescription': 'đơn đổi từ đơn 325437922\nVA362 Kem S &gt; Kem L\nVX157 xanh S &gt; Xanh L',
#     'customerId': 145843264,
#     'customerName': 'Quyên',
#     'customerEmail': None,
#     'customerMobile': '0917777736',
#     'customerAddress': 'Số 3, hẻm 8, nguyễn văn rốp, phường 4, tp tây ninh',
#     'shipToCityLocationId': 300,
#     'shipToDistrictLocationId': '784',
#     'customerCityId': 300,
#     'customerCity': 'Tây Ninh',
#     'customerDistrictId': 784,
#     'customerDistrict': 'Thành Phố Tây Ninh',
#     'shipToWardLocationId': 9829,
#     'customerWard': 'Phường 4',
#     'createdById': 2994812,
#     'createdByUserName': 'Nguyễn Thị Bích',
#     'createdByName': 'Nguyễn Thị Bích',
#     'saleId': 3102883,
#     'saleName': 'Đặng Thị Lâm Oanh',
#     'createdDateTime': '2024-01-06 11:18:15',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': -520000,
#     'trafficSourceId': 753533,
#     'trafficSourceName': 'Shopee',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105315',
#       'productName': 'Váy dáng xòe ngắn xếp ly đáp ngực - Xanh - L',
#       'productCode': 'VX157TT.LT1123-XA-L',
#       'productBarcode': '2000214265187',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231108_Cr01edd2nA.jpeg',
#       'price': '520000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': 0,
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '327772848',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333509269': {'id': 333509269,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Khách trả lại hàng',
#     'typeId': 14,
#     'moneyDiscount': 1030000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
# ...
#     'shipToCityLocationId': 255,
#     'shipToDistrictLocationId': '361',
#     'customerCityId': 255,
#     'customerCity': 'Hồ Chí Minh',
#     'customerDistrictId': 361,
#     'customerDistrict': 'Thành Phố Thủ Đức',
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': 2994812,
#     'createdByUserName': 'Nguyễn Thị Bích',
#     'createdByName': 'Nguyễn Thị Bích',
#     'saleId': 3131729,
#     'saleName': 'Trần Ánh Nhung',
#     'createdDateTime': '2024-01-06 11:31:06',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': -378000,
#     'trafficSourceId': 761591,
#     'trafficSourceName': 'Promotion',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39104634',
#       'productName': 'Quần suông xếp ly cạp - Đen - M',
#       'productCode': 'QX029TS.LP0923-DE-M',
#       'productBarcode': '2000214258370',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231009_p3IDpI8pyU.jpeg',
#       'price': '540000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '162000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '327863557',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333513802': {'id': 333513802,
#     'privateId': '24010667FHF404',
#     'shopOrderId': '24010667FHF404',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 24540,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 29,
#     'carrierName': 'SPX Express',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 34741,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'T******p',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******u, Phường Quảng An, Quận Tây Hồ, Hà Nội',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-06 11:23:16',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Đã xác nhận',
#     'statusCode': 'Confirmed',
#     'calcTotalMoney': 384460,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105958',
#       'productName': 'Váy dáng A can eo phối cổ đính cúc trang trí. - Ghi - L',
#       'productCode': 'VA327DT.LP1223-GH-L',
#       'productBarcode': '2000214271614',
#       'productImage': '',
#       'price': '409000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '24540',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333513827': {'id': 333513827,
#     'privateId': '24010667WW5RER',
#     'shopOrderId': '24010667WW5RER',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 10000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 16710,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'P******g',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******, Phường Đức Giang, Quận Long Biên, Hà Nội',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': 3123513,
#     'saleName': 'Lưu Hoàng Dương',
#     'createdDateTime': '2024-01-06 11:31:19',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Mới',
#     'statusCode': 'New',
#     'calcTotalMoney': 185000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '38518868',
#       'productName': 'Áo cadigan lông thỏ basic - Vàng - Free size',
#       'productCode': 'AL125LT.LP1022-VA-F',
#       'productBarcode': '2000204494023',
#       'productImage': '',
#       'price': '195000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '10000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333513945': {'id': 333513945,
#     'privateId': '24010667G5GQGS',
#     'shopOrderId': '24010667G5GQGS',
#     'channel': 42,
#     'saleChannel': 42,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Giao hàng tận nhà',
#     'typeId': 1,
#     'moneyDiscount': 20000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': '',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 53727,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': '',
#     'customerId': None,
#     'customerName': 'n******a',
#     'customerEmail': None,
#     'customerMobile': None,
#     'customerAddress': '******ường Tân Thành, Thành Phố Ninh Bình, Ninh Bình',
#     'shipToCityLocationId': None,
#     'shipToDistrictLocationId': None,
#     'customerCityId': None,
#     'customerCity': None,
#     'customerDistrictId': None,
#     'customerDistrict': None,
#     'shipToWardLocationId': None,
#     'customerWard': None,
#     'createdById': None,
#     'createdByUserName': '',
#     'createdByName': '',
#     'saleId': None,
#     'saleName': '',
#     'createdDateTime': '2024-01-06 11:23:37',
#     'deliveryDate': None,
#     'sendCarrierDate': None,
#     'statusName': 'Mới',
#     'statusCode': 'New',
#     'calcTotalMoney': 533000,
#     'trafficSourceId': None,
#     'trafficSourceName': '',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105030',
#       'productName': 'Áo blazer xẻ sau lệch - Be - M',
#       'productCode': 'AB066CH.LC1023-BE-M',
#       'productBarcode': '2000214262339',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231031_ehi92lUd90.jpeg',
#       'price': '553000',
#       'quantity': '1',
#       'weight': None,
#       'discount': '20000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333514134': {'id': 333514134,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Khách trả lại hàng',
#     'typeId': 14,
#     'moneyDiscount': 231000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 0,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': 'fs',
#     'customerId': 145839400,
#     'customerName': 'Hồng Thắm',
#     'customerEmail': None,
#     'customerMobile': '0969510157',
#     'customerAddress': '0969510157 phù khê đông xã phù khê từ sơn bắc ninh',
#     'shipToCityLocationId': 258,
#     'shipToDistrictLocationId': '429',
#     'customerCityId': 258,
#     'customerCity': 'Bắc Ninh',
#     'customerDistrictId': 429,
#     'customerDistrict': 'Thành Phố Từ Sơn',
#     'shipToWardLocationId': 4595,
#     'customerWard': 'Xã Phù Khê',
#     'createdById': 2994812,
#     'createdByUserName': 'Nguyễn Thị Bích',
#     'createdByName': 'Nguyễn Thị Bích',
#     'saleId': 3128527,
#     'saleName': 'Nguyễn Thị Hiền',
#     'createdDateTime': '2024-01-06 11:32:28',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': -999000,
#     'trafficSourceId': 753532,
#     'trafficSourceName': 'Live',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105853',
#       'productName': 'Chân váy dạ phối viền gấu - Be - M',
#       'productCode': 'CA106DT.LP1223-BE-M',
#       'productBarcode': '2000214270563',
#       'productImage': '',
#       'price': '380000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '71366',
#       'description': '',
#       'imei': '',
#       'giftProducts': []},
#      {'productId': '39105848',
#       'productName': 'Áo khoác dạ phối cổ nơ - Be - M',
#       'productCode': 'AK063DT.LP1223-BE-M',
#       'productBarcode': '2000214270518',
#       'productImage': '',
#       'price': '850000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '159634',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '329647779',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333514427': {'id': 333514427,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Khách trả lại hàng',
#     'typeId': 14,
#     'moneyDiscount': 0,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 12,
#     'carrierName': 'Tự Vận Chuyển',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 0,
#     'codFee': 0,
#     'customerShipFee': 0,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': 'fs',
#     'customerId': 145843027,
#     'customerName': 'Cái Thu Trà',
#     'customerEmail': None,
#     'customerMobile': '0905631114',
#     'customerAddress': 'Chị trà. Tổ dân phố 8 phú Lộc TT Huế',
#     'shipToCityLocationId': 268,
#     'shipToDistrictLocationId': '385',
#     'customerCityId': 268,
#     'customerCity': 'Thừa Thiên Huế',
#     'customerDistrictId': 385,
#     'customerDistrict': 'Huyện Phú Lộc',
#     'shipToWardLocationId': 7874,
#     'customerWard': 'Thị trấn Phú Lộc',
#     'createdById': 2994812,
#     'createdByUserName': 'Nguyễn Thị Bích',
#     'createdByName': 'Nguyễn Thị Bích',
#     'saleId': 3097775,
#     'saleName': 'Vũ Thị Bảo Yến',
#     'createdDateTime': '2024-01-06 11:33:11',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Thành công',
#     'statusCode': 'Success',
#     'calcTotalMoney': -360000,
#     'trafficSourceId': 753531,
#     'trafficSourceName': 'Page',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '39105488',
#       'productName': 'Chân váy tafta dáng A ly súp - Đen - L',
#       'productCode': 'CA098TT.LP1123-DE-L',
#       'productBarcode': '2000214266917',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20231116_wrQ7nptVaO.jpeg',
#       'price': '360000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': 0,
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': [],
#     'couponCode': None,
#     'returnFromOrderId': '326435613',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}},
#    '333514489': {'id': 333514489,
#     'privateId': None,
#     'shopOrderId': None,
#     'channel': 1,
#     'saleChannel': 1,
#     'merchantTrackingNumber': None,
#     'depotId': 41944,
#     'handoverId': None,
#     'depotName': 'Kho Online',
#     'type': 'Đặt trước',
#     'typeId': 3,
#     'moneyDiscount': 295000,
#     'moneyDeposit': 0,
#     'moneyTransfer': 0,
#     'depositAccount': 'Đổi hàng COD',
#     'transferAccount': '',
#     'usedPoints': 0,
#     'moneyUsedPoints': 0,
#     'carrierId': 8,
#     'carrierName': 'Giao hàng tiết kiệm',
#     'serviceId': None,
#     'serviceName': '',
#     'carrierCode': None,
#     'shipFee': 26000,
#     'codFee': 0,
#     'customerShipFee': 30000,
#     'returnFee': 0,
#     'overWeightShipFee': 0,
#     'declaredFee': 0,
#     'description': '',
#     'privateDescription': 'CH\nZL0655',
#     'customerId': 145835091,
#     'customerName': 'Phạm thị Hương',
#     'customerEmail': 'phamhuong2027@gmail.com',
#     'customerMobile': '0974615698',
#     'customerAddress': 'hẻm 44 đường an nhơn, kp tân phú 1, phường tân bình, dĩ an, bình dương',
#     'shipToCityLocationId': 260,
#     'shipToDistrictLocationId': '441',
#     'customerCityId': 260,
#     'customerCity': 'Bình Dương',
#     'customerDistrictId': 441,
#     'customerDistrict': 'Thành Phố Dĩ An',
#     'shipToWardLocationId': 9987,
#     'customerWard': 'Phường Tân Bình',
#     'createdById': 3131729,
#     'createdByUserName': 'Trần Ánh Nhung',
#     'createdByName': 'Trần Ánh Nhung',
#     'saleId': 3131729,
#     'saleName': 'Trần Ánh Nhung',
#     'createdDateTime': '2024-01-06 11:33:21',
#     'deliveryDate': '2024-01-06',
#     'sendCarrierDate': None,
#     'statusName': 'Mới',
#     'statusCode': 'New',
#     'calcTotalMoney': 325000,
#     'trafficSourceId': 761591,
#     'trafficSourceName': 'Promotion',
#     'affiliateCode': '',
#     'affiliateBonusCash': 0,
#     'affiliateBonusPercent': 0,
#     'products': [{'productId': '38096669',
#       'productName': 'Váy dáng A cổ cách điệu phối đai bọc thanh lịch - Kem - M',
#       'productCode': 'VA148TT.BC0622-KE-M',
#       'productBarcode': '2000201717125',
#       'productImage': 'https://pos.nvncdn.com/fa49eb-41931/ps/20220608_hbRQgTVSSyxhZTx2X2bAHJnE.jpg',
#       'price': '590000',
#       'quantity': '1',
#       'weight': '10',
#       'discount': '295000',
#       'description': '',
#       'imei': '',
#       'giftProducts': []}],
#     'tags': {'4699': 'Xin hàng PNT'},
#     'couponCode': None,
#     'returnFromOrderId': '',
#     'utmSource': '',
#     'utmMedium': '',
#     'utmCampaign': '',
#     'facebook': {'fanpageId': None, 'adId': None}}}}}

# %%
try:
    asdasd
except:
    print('Lỗi')
# Out:
# Lỗi

# %%
ádasd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ádasd
#
# NameError: name 'ádasd' is not defined
